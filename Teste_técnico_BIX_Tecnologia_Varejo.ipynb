# %% [markdown]
# <a href="https://colab.research.google.com/github/lucassanroman/Portfolio/blob/main/Teste_t%C3%A9cnico_BIX_Tecnologia_Varejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BIX Tecnologia - Teste Técnico - Varejo

# %% [markdown]
# As perguntas do teste simulam a análise de dados e tomada de decisão a partir de uma base de dados de um cliente fictício.
#
#
#
# O que está sendo avaliado:
#
#
#
# *   Conceitos de Data Science (DS) e Machine Learning (ML);
# *   Manipulação de dados;
# *   Estatística básica;
# *   Criação e avaliação de gráficos;
# *   Entendimento de negócio.

# %% [markdown]
# ##**A base de dados possui quatro divisões:**
#
#
#
# 1.   **Dados de venda**
#
# - ID: identificador único de uma venda
# - ProductID: identificador único de um produto
# - ClientID: identificador único de um cliente
# - Discount: desconto aplicado em uma venda
# - UnitPrice: preço unitário de um produto vendido
# - Quantity: quantidade de produto vendido em uma venda
# - StoreID: identificador único de uma loja
# - Date: data de uma venda
#
#
# 2. **Dados de consumidores**
#
# - ID: identificador único de um consumidor
# - City: cidade/localidade onde um consumidor fez a compra
# - State: Unidade Federativa onde um consumidor fez a compra
# - DateOfBirth: data de nascimento de um consumidor
# - Sex: sexo de um consumidor
#
#
# 3. **Dados de lojas**
#
# - ID: identificador único de uma loja
# - Name: cidade/localidade de uma loja
# - State: Unidade Federativa de uma loja
#
#
# 4. **Dados de produto**
#
# - ID: identificador único de um produto
# - Name: nome de um produto
# - Size: tamanho de um produto

# %% [markdown]
# #Importando Pandas e armazenando os datasets

# %%
import pandas as pd

# %%
dados_vendas = pd.read_csv('dados_de_venda.csv')
dados_produto = pd.read_csv('dados_de_produto.csv')
dados_consumidores = pd.read_csv('dados_de_consumidores.csv')
dados_lojas = pd.read_csv('dados_de_lojas.csv')

# %% [markdown]
# #Visualizando e tratando os dados:

# %%
dados_vendas.head(20)
# Out:
#     Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 0          NaN         NaN                               NaN
# 1          NaN         NaN                               NaN
# 2          NaN         NaN                               NaN
# 3          NaN         NaN                                ID
# 4          NaN         NaN  80260d682079b6090c8285b398c50d97
# 5          NaN         NaN  3275736da1234f55d52bdf09d86b93bc
# 6          NaN         NaN  f3513eec8f1434b5b7e04ddf3598df40
# 7          NaN         NaN  7180475b60fe6bbbde424d39704a1177
# 8          NaN         NaN  76600853a200fe87e141adae6b35674c
# 9          NaN         NaN  7ab64f42a8f9ab290e920eed320d7e60
# 10         NaN         NaN  b35a771164a9defa3b4767f1b66918b1
# 11         NaN         NaN  28618be7d166aad45ab14e9bca43cc19
# 12         NaN         NaN  b8b9625b11ffbc12df779c20935997c2
# 13         NaN         NaN  42d0d6be3900c1f50190096f216695b1
# ...

# %%
dados_produto.head(10)
# Out:
#                                   ID             Name Size
# 0  00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1  00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2  00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3  00088930e925c41fd95ebfe695fd26551             Thor    P
# 4  00088930e925c41fd95ebfe695fd26552             Thor    M
# 5  00088930e925c41fd95ebfe695fd26553             Thor    G
# 6  0009406fd7479715e4bef61dd91f24621         Deadpool    P
# 7  0009406fd7479715e4bef61dd91f24622         Deadpool    M
# 8  0009406fd7479715e4bef61dd91f24623         Deadpool    G
# 9  000b8f95fcb9e0096488278317764d191    Pantera Negra    P

# %%
dados_consumidores.head(10)
# Out:
#       ID            City State DateOfBirth     Sex
# 0  14001        Curitiba    PR   6/28/1985   Homem
# 1  14002   Florianópolis    SC   1/10/1987   Homem
# 2  14003  Rio de Janeiro    RJ   11/5/1979   Homem
# 3  14004  Rio de Janeiro    RJ  11/25/1983  Mulher
# 4  14005   Florianópolis    SC    4/7/1969   Homem
# 5  14006  Rio de Janeiro    RJ   8/17/1951  Mulher
# 6  14007       São Paulo    SP   1/23/1981   Homem
# 7  14008       São Paulo    SP   12/7/1971   Homem
# 8  14009  Rio de Janeiro    RJ   12/4/1962  Mulher
# 9  14010  Rio de Janeiro    RJ   9/13/1972   Homem

# %%
dados_lojas.head(7)
# Out:
#    ID            Name State
# 0   1   Florianópolis    SC
# 1   2  Rio de Janeiro    RJ
# 2   3    Porto Alegre    RS
# 3   4        Curitiba    PR
# 4   7       São Paulo    SP
# 5   9  Belo Horizonte    MG
# 6  22          Online    na

# %%
dados_vendas.drop(columns=['Unnamed: 0', 'Unnamed: 1'], inplace=True)

# %%
dados_vendas.columns = dados_vendas.iloc[3]

# %%
dados_vendas.drop([0, 1, 2, 3], inplace=True)

# %%
dados_vendas.head(10)
# Out:
# 3                                 ID                          ProductID  \
# 4   80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 5   3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 6   f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 7   7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8   76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 9   7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 10  b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# 11  28618be7d166aad45ab14e9bca43cc19  00126f27c813603687e6ce486d909d013
# 12  b8b9625b11ffbc12df779c20935997c2  001795ec6f1b187d37335e1c4704762e3
# 13  42d0d6be3900c1f50190096f216695b1  001c5d71ac6ad696d22315953758fa043
#
# 3  ClientID Discount UnitPrice Quantity StoreID        Date
# 4     14001     0,08     249,2        1       4  12/10/2018
# ...

# %%
dados_vendas.reset_index(drop=True, inplace=True)

# %%
dados_vendas.head()
# Out:
# 3                                ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
# 3 ClientID Discount UnitPrice Quantity StoreID        Date
# 0    14001     0,08     249,2        1       4  12/10/2018
# 1    14001      0,1     162,4        1       4   4/25/2019
# 2    14001      0,1     194,6        1       4   7/17/2019
# 3    14002      0,1     201,6        2       1   4/10/2018
# 4    14002      0,1       406        1       1   1/21/2019

# %%
dados_vendas.isna().values.any()
# Out:
# False

# %%
dados_consumidores.isna().values.any()
# Out:
# False

# %%
dados_lojas.isna().values.any()
# Out:
# False

# %%
dados_produto.isna().values.any()
# Out:
# False

# %% [markdown]
# ##Análise prévia:

# %%
dados_vendas.shape
# Out:
# (32753, 8)

# %%
dados_vendas.describe()
# Out:
# 3                                     ID                          ProductID  \
# count                              32753                              32753
# unique                             32753                                 73
# top     80260d682079b6090c8285b398c50d97  002ec297b1b00fb9dde7ee6ac24b67713
# freq                                   1                                966
#
# 3      ClientID Discount UnitPrice Quantity StoreID        Date
# count     32753    32753     32753    32753   32753       32753
# unique    13650        2        21        3       7         690
# top       17631      0,1     233,8        1       1  12/24/2018
# freq          9    21309      2776    30868    8230          99

# %% [markdown]
# ### Produto mais vendido:

# %%
dados_vendas.ProductID.value_counts()
# Out:
# 002ec297b1b00fb9dde7ee6ac24b67713    966
# 002d4ea7c04739c130bb74d7e7cd16943    963
# 001c5d71ac6ad696d22315953758fa043    944
# 0011c512eb256aa0dbbb544d8dffcf6e3    940
# 0030026a6ddb3b2d1d4bc225b4b4c4da3    939
#                                     ...
# 00088930e925c41fd95ebfe695fd26552    205
# 00210e41887c2a8ef9f791ebc780cc362    204
# 002ec297b1b00fb9dde7ee6ac24b67711    202
# 002552c0663708129c0019cc97552d7d2    200
# 001b237c0e9bb435f2e54071129237e92    197
# Name: ProductID, Length: 73, dtype: int64

# %%
dados_produto.query("ID == '002ec297b1b00fb9dde7ee6ac24b67713'") #Produto mais vendido
# Out:
#                                    ID     Name Size
# 62  002ec297b1b00fb9dde7ee6ac24b67713  Bazinga    G

# %%
dados_produto.shape
# Out:
# (73, 3)

# %% [markdown]
# ###Produto menos vendido:

# %%
dados_vendas.ProductID.value_counts().tail()
# Out:
# 00088930e925c41fd95ebfe695fd26552    205
# 00210e41887c2a8ef9f791ebc780cc362    204
# 002ec297b1b00fb9dde7ee6ac24b67711    202
# 002552c0663708129c0019cc97552d7d2    200
# 001b237c0e9bb435f2e54071129237e92    197
# Name: ProductID, dtype: int64

# %%
dados_produto.query("ID == '001b237c0e9bb435f2e54071129237e92'") #Produto menos vendido
# Out:
#                                    ID    Name Size
# 25  001b237c0e9bb435f2e54071129237e92  Thanos    M

# %% [markdown]
# ###Maiores consumidores:

# %%
dados_vendas.ClientID.value_counts() #As maiores compras efetuadas foram por clientes que compraram 9 produtos.
# Out:
# 17631    9
# 22056    9
# 19089    9
# 26177    9
# 15499    8
#         ..
# 23259    1
# 23255    1
# 23254    1
# 23252    1
# 28695    1
# Name: ClientID, Length: 13650, dtype: int64

# %%
dados_vendas.ClientID.value_counts().mean().round(2) #A média de compra por cliente é de 2.4 produtos
# Out:
# 2.4

# %%
top_clientes = dados_consumidores.query("ID == 17631")
top_clientes = top_clientes.append(dados_consumidores.query("ID == 22056"))
top_clientes = top_clientes.append(dados_consumidores.query("ID == 19089"))
top_clientes = top_clientes.append(dados_consumidores.query("ID == 26177")) #Criando um dataframe com os 4 maiores clientes

# %%
top_clientes #Os 4 maiores consumidores
# Out:
#           ID            City State DateOfBirth     Sex
# 3612   17631  Rio de Janeiro    RJ  12/11/1970   Homem
# 7780   22056   Florianópolis    SC  10/30/1959   Homem
# 5062   19089       São Paulo    SP  11/21/1986   Homem
# 11419  26177        Curitiba    PR  12/30/1992  Mulher

# %% [markdown]
# ###Produtos mais caros:

# %%
dados_vendas.UnitPrice.max() #Verificando o maior valor da coluna UnitPrice
# Out:
# '686'

# %%
dados_vendas['ProductID'].loc[dados_vendas.UnitPrice == '686'].unique() #Buscando os produtos com o valor correspondente
# Out:
# array(['00250175f79f584c14ab5cecd80553cd3',
#        '00250175f79f584c14ab5cecd80553cd1',
#        '00250175f79f584c14ab5cecd80553cd2'], dtype=object)

# %%
produtos_mais_caros = dados_produto.query("ID == '00250175f79f584c14ab5cecd80553cd3'")
produtos_mais_caros = produtos_mais_caros.append(dados_produto.query("ID == '00250175f79f584c14ab5cecd80553cd1'"))
produtos_mais_caros = produtos_mais_caros.append(dados_produto.query("ID == '00250175f79f584c14ab5cecd80553cd2'"))
produtos_mais_caros #Criando dataframe dos produtos mais caros
# Out:
#                                    ID      Name Size
# 44  00250175f79f584c14ab5cecd80553cd3  BIXDream    G
# 42  00250175f79f584c14ab5cecd80553cd1  BIXDream    P
# 43  00250175f79f584c14ab5cecd80553cd2  BIXDream    M

# %% [markdown]
# ###Produtos mais baratos:

# %%
dados_vendas.UnitPrice.min() #Verificando o valor do produto mais barato
# Out:
# '114,8'

# %%
dados_vendas['ProductID'].loc[dados_vendas.UnitPrice == '114,8'].unique() #Buscando no dataset o produto com o valor correspondente
# Out:
# array(['00126f27c813603687e6ce486d909d013',
#        '00126f27c813603687e6ce486d909d012',
#        '00126f27c813603687e6ce486d909d011'], dtype=object)

# %%
produtos_mais_baratos = dados_produto.query("ID == '00126f27c813603687e6ce486d909d013'")
produtos_mais_baratos = produtos_mais_baratos.append(dados_produto.query("ID == '00126f27c813603687e6ce486d909d012'"))
produtos_mais_baratos = produtos_mais_baratos.append(dados_produto.query("ID == '00126f27c813603687e6ce486d909d011'"))
produtos_mais_baratos #Criando um dataframe com os produtos mais baratos
# Out:
#                                    ID     Name Size
# 20  00126f27c813603687e6ce486d909d013  Coringa    G
# 19  00126f27c813603687e6ce486d909d012  Coringa    M
# 18  00126f27c813603687e6ce486d909d011  Coringa    P

# %% [markdown]
# ###Convertendo o campo Date para o tipo Date

# %%
dados_vendas.Date.dtype
# Out:
# dtype('O')

# %%
# df['Data'] = pd.to_datetime(df.Data)
dados_vendas.Date = pd.to_datetime(dados_vendas.Date)
dados_vendas.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
dados_vendas.Date.max()
# Out:
# Timestamp('2020-01-31 00:00:00')

# %%
dados_vendas.Date.min()
# Out:
# Timestamp('2018-03-01 00:00:00')

# %% [markdown]
# **O dataset compreende as datas de 2018-03-01 até 2020-01-31**

# %% [markdown]
# ###Lojas que mais venderam:

# %%
dados_lojas.head(7)
# Out:
#    ID            Name State
# 0   1   Florianópolis    SC
# 1   2  Rio de Janeiro    RJ
# 2   3    Porto Alegre    RS
# 3   4        Curitiba    PR
# 4   7       São Paulo    SP
# 5   9  Belo Horizonte    MG
# 6  22          Online    na

# %%
ranking_lojas = dados_vendas.StoreID.value_counts()
ranking_lojas = pd.DataFrame(ranking_lojas)

# %%
ranking_lojas.reset_index(inplace=True)

# %%
ranking_lojas.columns = ['StoreID', 'Vendas']

# %%
import seaborn as sns
ax = sns.barplot(x=ranking_lojas.StoreID, y=ranking_lojas.Vendas)
ax.figure.set_size_inches(12, 6)
ax.set_xticklabels(dados_lojas.Name)
ax.set_xlabel('Lojas')
ax
# Out:
# <AxesSubplot:xlabel='Lojas', ylabel='Vendas'>

# %% [markdown]
# ###Receita total por loja

# %%
dados_vendas.head()
# Out:
# 3                                ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
# 3 ClientID Discount UnitPrice Quantity StoreID       Date
# 0    14001     0,08     249,2        1       4 2018-12-10
# 1    14001      0,1     162,4        1       4 2019-04-25
# 2    14001      0,1     194,6        1       4 2019-07-17
# 3    14002      0,1     201,6        2       1 2018-04-10
# 4    14002      0,1       406        1       1 2019-01-21

# %%
dados_vendas.dtypes
# Out:
# 3
# ID                   object
# ProductID            object
# ClientID             object
# Discount             object
# UnitPrice            object
# Quantity             object
# StoreID              object
# Date         datetime64[ns]
# dtype: object

# %%
#Substituindo as vírgulas por pontos para utilizar nos cálculos
dados_vendas.UnitPrice = dados_vendas.UnitPrice.str.replace(',', '.')
dados_vendas.Discount = dados_vendas.Discount.str.replace(',', '.')

# %%
#Convertendo os valores de string para int e float
dados_vendas = dados_vendas.astype({'Quantity': 'int', 'UnitPrice': 'float', 'Discount':'float'})

# %%
receita_por_loja = (dados_vendas.Quantity * dados_vendas.UnitPrice).groupby(dados_vendas.StoreID).sum() #Multiplicando as quantidades vendidas pelo valor dos produtos, e agrupando a soma por loja
receita_por_loja = pd.DataFrame(receita_por_loja)
receita_por_loja #Tabela da receita bruta por loja
# Out:
#                  0
# StoreID
# 1        1940307.6
# 2        1588476.4
# 22        217596.4
# 3        1441864.2
# 4        1228606.4
# 7         838198.2
# 9         433844.6

# %%
receita_por_loja.columns = ['Vendas']
receita_por_loja = receita_por_loja.sort_values('Vendas', ascending=False) #Re-ordenando a tabela de forma decrescente
receita_por_loja
# Out:
#             Vendas
# StoreID
# 1        1940307.6
# 2        1588476.4
# 3        1441864.2
# 4        1228606.4
# 7         838198.2
# 9         433844.6
# 22        217596.4

# %%
ax = sns.barplot(x=receita_por_loja.index, y=receita_por_loja.Vendas)
ax.figure.set_size_inches(12, 6)
ax.set_xticklabels(dados_lojas.Name)
ax.set_xlabel('Lojas')
ax
# Out:
# <AxesSubplot:xlabel='Lojas', ylabel='Vendas'>

# %% [markdown]
# ###Informações sobre os consumidores:

# %%
dados_consumidores.head()
# Out:
#       ID            City State DateOfBirth     Sex
# 0  14001        Curitiba    PR   6/28/1985   Homem
# 1  14002   Florianópolis    SC   1/10/1987   Homem
# 2  14003  Rio de Janeiro    RJ   11/5/1979   Homem
# 3  14004  Rio de Janeiro    RJ  11/25/1983  Mulher
# 4  14005   Florianópolis    SC    4/7/1969   Homem

# %% [markdown]
# ###Sexo dos consumidores:

# %%
dados_consumidores.Sex.value_counts()
# Out:
# Homem     11972
# Mulher     1678
# Name: Sex, dtype: int64

# %%
frequencia = dados_consumidores.Sex.value_counts(normalize=True)*100 #87% dos consumidores são homens
frequencia = pd.DataFrame(frequencia)
frequencia
# Out:
#              Sex
# Homem   87.70696
# Mulher  12.29304

# %%
import matplotlib.pyplot as plt

labels = ['Homem', 'Mulher']
plt.pie(frequencia.Sex, labels = labels, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ###Idade dos consumidores:

# %%
dados_consumidores.DateOfBirth.dtypes
# Out:
# dtype('O')

# %%
import numpy as np
now = pd.Timestamp('now') #Criando variável com a data atual

# %%
# df['Data'] = pd.to_datetime(df.Data)
dados_consumidores.DateOfBirth = pd.to_datetime(dados_consumidores.DateOfBirth) #Convertendo a coluna DateOfBirth para tipo Date
dados_consumidores.DateOfBirth.dtypes
# Out:
# dtype('<M8[ns]')

# %%
idade_consumidores = (now - dados_consumidores.DateOfBirth).astype('<m8[Y]') #Pegando a idade dos consumidores
idade_consumidores = pd.DataFrame(idade_consumidores)
idade_consumidores
# Out:
#        DateOfBirth
# 0             37.0
# 1             36.0
# 2             43.0
# 3             39.0
# 4             53.0
# ...            ...
# 13645         24.0
# 13646         67.0
# 13647         37.0
# 13648         40.0
# 13649         61.0
#
# [13650 rows x 1 columns]

# %%
idade_consumidores.DateOfBirth.mean().round(2) #Média de idade dos consumidores
# Out:
# 44.05

# %% [markdown]
# ###Filtrando vendas por produto e por ano:

# %%
dados_produto.loc[dados_produto.Name == 'Iron Man'] #Selecionando um produto por nome na tabela de produtos
# Out:
#                                    ID      Name Size
# 57  002d4ea7c04739c130bb74d7e7cd16941  Iron Man    P
# 58  002d4ea7c04739c130bb74d7e7cd16942  Iron Man    M
# 59  002d4ea7c04739c130bb74d7e7cd16943  Iron Man    G

# %%
venda_iron_man = dados_vendas.loc[dados_vendas.ProductID == '002d4ea7c04739c130bb74d7e7cd16943'] #Encontrando as vendas do produto selecionado
venda_iron_man
# Out:
# 3                                    ID                          ProductID  \
# 42     85647e1ff3e4b10814f375af01c38836  002d4ea7c04739c130bb74d7e7cd16943
# 106    ec451fb3a1ee5782fef4937473a9ffac  002d4ea7c04739c130bb74d7e7cd16943
# 170    c68e47bd3dab5dd575a6c65848663923  002d4ea7c04739c130bb74d7e7cd16943
# 203    a97c9b194a026ac3e75726c485f6e8ea  002d4ea7c04739c130bb74d7e7cd16943
# 221    ea110ced6459b4dc6c73e0b2367077e9  002d4ea7c04739c130bb74d7e7cd16943
# ...                                 ...                                ...
# 32626  ffdb12bf66b3d0145d09d962745a05f6  002d4ea7c04739c130bb74d7e7cd16943
# 32680  53802dd14f00658bd63315e41be39610  002d4ea7c04739c130bb74d7e7cd16943
# 32710  bb5a519e352b45b714192a02ffe25681  002d4ea7c04739c130bb74d7e7cd16943
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
#
# 3     ClientID  Discount  UnitPrice  Quantity StoreID       Date
# ...

# %%
#(df['Data'] >= '2018-01-01') & (df['Data'] <= '2019-02-10')
vendas_iron_man_2019 = venda_iron_man.loc[(venda_iron_man.Date >= '2019-01-01') & (venda_iron_man.Date <= '2019-12-31')] #Filtrando as vendas do produto dentro do ano de 2019
vendas_iron_man_2019
# Out:
# 3                                    ID                          ProductID  \
# 203    a97c9b194a026ac3e75726c485f6e8ea  002d4ea7c04739c130bb74d7e7cd16943
# 221    ea110ced6459b4dc6c73e0b2367077e9  002d4ea7c04739c130bb74d7e7cd16943
# 238    89fb8b371b28dcc037a9c1f798eacc81  002d4ea7c04739c130bb74d7e7cd16943
# 323    51efa345a1180ca3879442a31b0a265a  002d4ea7c04739c130bb74d7e7cd16943
# 487    f89525a2a79be7efb2afb5844cf2652d  002d4ea7c04739c130bb74d7e7cd16943
# ...                                 ...                                ...
# 32491  46f0668d5961419489c708d57e9e99bb  002d4ea7c04739c130bb74d7e7cd16943
# 32599  e9a673444938dfb3ee73bc31383f2921  002d4ea7c04739c130bb74d7e7cd16943
# 32626  ffdb12bf66b3d0145d09d962745a05f6  002d4ea7c04739c130bb74d7e7cd16943
# 32680  53802dd14f00658bd63315e41be39610  002d4ea7c04739c130bb74d7e7cd16943
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
#
# 3     ClientID  Discount  UnitPrice  Quantity StoreID       Date
# ...

# %% [markdown]
# ###Correlação entre idade e vendas:

# %%
import statsmodels.api as sm

# %%
dados_vendas['Total Value'] = (dados_vendas.Quantity * dados_vendas.UnitPrice) - (((dados_vendas.Quantity * dados_vendas.UnitPrice) / 100) * (dados_vendas.Discount * 100)) #Criando uma nova coluna com o valor total. Multiplicando a quantidade pelo preço e subtraindo o desconto.
dados_vendas.head()
# Out:
# 3                                ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
# 3 ClientID  Discount  UnitPrice  Quantity StoreID       Date  Total Value
# 0    14001      0.08      249.2         1       4 2018-12-10      229.264
# 1    14001      0.10      162.4         1       4 2019-04-25      146.160
# 2    14001      0.10      194.6         1       4 2019-07-17      175.140
# 3    14002      0.10      201.6         2       1 2018-04-10      362.880
# 4    14002      0.10      406.0         1       1 2019-01-21      365.400

# %%
total_por_cliente = dados_vendas.groupby(dados_vendas.ClientID)['Total Value'].sum()
total_por_cliente = pd.DataFrame(total_por_cliente)
total_por_cliente
# Out:
#           Total Value
# ClientID
# 14001         550.564
# 14002        1299.032
# 14003         541.800
# 14004         867.692
# 14005         224.280
# ...               ...
# 28689         554.400
# 28691         229.320
# 28692         790.020
# 28694        1307.572
# 28695         229.320
#
# [13650 rows x 1 columns]

# %%
total_por_cliente['Age'] = idade_consumidores.values
total_por_cliente
# Out:
#           Total Value   Age
# ClientID
# 14001         550.564  37.0
# 14002        1299.032  36.0
# 14003         541.800  43.0
# 14004         867.692  39.0
# 14005         224.280  53.0
# ...               ...   ...
# 28689         554.400  24.0
# 28691         229.320  67.0
# 28692         790.020  37.0
# 28694        1307.572  40.0
# 28695         229.320  61.0
#
# [13650 rows x 2 columns]

# %%
total_por_cliente.corr() #Valor bem próximo de 0, indicando não ter correlação.
# Out:
#              Total Value       Age
# Total Value     1.000000 -0.010728
# Age            -0.010728  1.000000

# %%
Y = total_por_cliente['Total Value']
X = sm.add_constant(total_por_cliente.Age)

# %%
regressao = sm.OLS(Y, X).fit()

# %%
print(regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Total Value   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.571
# Date:                Fri, 03 Mar 2023   Prob (F-statistic):              0.210
# Time:                        13:29:32   Log-Likelihood:                -98725.
# No. Observations:               13650   AIC:                         1.975e+05
# Df Residuals:                   13648   BIC:                         1.975e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        524.1284     10.933     47.941      0.000     502.699     545.558
# ...

# %%
total_por_cliente['Previsão'] = regressao.predict()
total_por_cliente
# Out:
#           Total Value   Age    Previsão
# ClientID
# 14001         550.564  37.0  513.021328
# 14002        1299.032  36.0  513.321519
# 14003         541.800  43.0  511.220179
# 14004         867.692  39.0  512.420945
# 14005         224.280  53.0  508.218266
# ...               ...   ...         ...
# 28689         554.400  24.0  516.923815
# 28691         229.320  67.0  504.015586
# 28692         790.020  37.0  513.021328
# 28694        1307.572  40.0  512.120753
# 28695         229.320  61.0  505.816735
#
# [13650 rows x 3 columns]

# %% [markdown]
# **A previsão mostra realmente que a idade do consumidor não ter correlação com o gasto, como havíamos conferido na matriz de correlação**
#
# **Os dados mantém uma média independente da idade**

# %% [markdown]
# ###Vendas por ano:

# %%
##(df['Data'] >= '2018-01-01') & (df['Data'] <= '2019-02-10')
vendas_2018 = dados_vendas.loc[(dados_vendas.Date >= '2018-01-01') & (dados_vendas.Date <= '2018-12-31')]
vendas_2018
# Out:
# 3                                    ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      b8b9625b11ffbc12df779c20935997c2  001795ec6f1b187d37335e1c4704762e3
# 9      42d0d6be3900c1f50190096f216695b1  001c5d71ac6ad696d22315953758fa043
# 10     1df7ded3518147b95eababb6620f007c  002c6dab60557c48cfd6c2222ef7fd763
# ...                                 ...                                ...
# 32746  38886f218185dea64ae0c39a629d89de  001c5d71ac6ad696d22315953758fa043
# 32747  220e9a646a779158c953b9bf145606ab  00066f42aeeb9f3007548bb9d3f33c382
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
vendas_2019 = dados_vendas.loc[(dados_vendas.Date >= '2019-01-01') & (dados_vendas.Date <= '2019-12-31')]
vendas_2019
# Out:
# 3                                    ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# 32733  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# 32739  18a83c7532fc2dc3a10fd55ff3655588  0011c512eb256aa0dbbb544d8dffcf6e1
# 32740  d105b386fa5b4aab107c43ba2760f64b  002552c0663708129c0019cc97552d7d3
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
#
# ...

# %%
vendas_2020 = dados_vendas.loc[(dados_vendas.Date >= '2020-01-01') & (dados_vendas.Date <= '2020-12-31')]
vendas_2020
# Out:
# 3                                    ID                          ProductID  \
# 44     638c43326cd8c7403a2bf818e46b779e  002c6dab60557c48cfd6c2222ef7fd763
# 115    cace823f92c444647ed99fa6ecd8e582  003128f981470c3e5a2e7445e4a771cd4
# 116    a728a784b0cb1c9e387f984db61c0810  002159fe700ed3521f46cfcf6e941c763
# 150    3f7d4510666c881c335f9ca51b9db9cb  000b8f95fcb9e0096488278317764d193
# 155    8c4e6faa1d8e601c6d90c6ac2ad3c1db  0011c512eb256aa0dbbb544d8dffcf6e3
# ...                                 ...                                ...
# 32510  98f0aebfebbcb44cfb1e1057ea15099e  001b237c0e9bb435f2e54071129237e93
# 32548  357b3e52b16c253a241494d7350a7f3d  002ec297b1b00fb9dde7ee6ac24b67713
# 32615  dfaba9e54da21d5c9ca002e103b5496a  002552c0663708129c0019cc97552d7d3
# 32620  832c61671b530bdc7d56880581bc2146  001b72dfd63e9833e8c02742adf472e33
# 32651  e73c4ecd46f3549fd9ebcdfab800cd28  001c5d71ac6ad696d22315953758fa043
#
# ...

# %%
vendas_2018['Total Value'].sum().round(2)
# Out:
# 3289660.81

# %%
vendas_2019['Total Value'].sum().round(2)
# Out:
# 3531181.14

# %%
vendas_2020['Total Value'].sum().round(2)
# Out:
# 153009.36

# %%
vendas_2018.Quantity.sum()
# Out:
# 18494

# %%
vendas_2019.Quantity.sum()
# Out:
# 15412

# %%
vendas_2020.Quantity.sum()
# Out:
# 768

# %% [markdown]
# **É possível verificar que 2019 efetuou menos vendas que 2018, porém, a receita foi maior**

# %% [markdown]
# ###Vendas por mês:

# %%
#df['month'] = df['datetime_utc'].dt.month
vendas_2018['Mes'] = vendas_2018.Date.dt.month
vendas_2018
# Out:
# <ipython-input-80-21567bb9f93a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_2018['Mes'] = vendas_2018.Date.dt.month
# 3                                    ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 8      b8b9625b11ffbc12df779c20935997c2  001795ec6f1b187d37335e1c4704762e3
# 9      42d0d6be3900c1f50190096f216695b1  001c5d71ac6ad696d22315953758fa043
# 10     1df7ded3518147b95eababb6620f007c  002c6dab60557c48cfd6c2222ef7fd763
# ...                                 ...                                ...
# ...

# %%
vendas_2019['Mes'] = vendas_2019.Date.dt.month
vendas_2019
# Out:
# <ipython-input-81-1372d9d931cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_2019['Mes'] = vendas_2019.Date.dt.month
# 3                                    ID                          ProductID  \
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# 5      7ab64f42a8f9ab290e920eed320d7e60  002552c0663708129c0019cc97552d7d3
# 6      b35a771164a9defa3b4767f1b66918b1  002959d7a0b0990fe2d69988affcbc803
# ...                                 ...                                ...
# ...

# %%
vendas_2020['Mes'] = vendas_2020.Date.dt.month
vendas_2020
# Out:
# <ipython-input-82-f9d513908225>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendas_2020['Mes'] = vendas_2020.Date.dt.month
# 3                                    ID                          ProductID  \
# 44     638c43326cd8c7403a2bf818e46b779e  002c6dab60557c48cfd6c2222ef7fd763
# 115    cace823f92c444647ed99fa6ecd8e582  003128f981470c3e5a2e7445e4a771cd4
# 116    a728a784b0cb1c9e387f984db61c0810  002159fe700ed3521f46cfcf6e941c763
# 150    3f7d4510666c881c335f9ca51b9db9cb  000b8f95fcb9e0096488278317764d193
# 155    8c4e6faa1d8e601c6d90c6ac2ad3c1db  0011c512eb256aa0dbbb544d8dffcf6e3
# ...                                 ...                                ...
# ...

# %%
vendas_2018_por_mes = vendas_2018.groupby('Mes')['Total Value'].sum()
vendas_2018_por_mes = pd.DataFrame(vendas_2018_por_mes)
vendas_2018_por_mes
# Out:
#      Total Value
# Mes
# 3     248866.380
# 4     249913.440
# 5     267427.440
# 6     349034.280
# 7     353761.380
# 8     355573.148
# 9     328287.120
# 10    291943.260
# 11    370068.300
# 12    474786.060

# %%
vendas_2018_por_mes.reset_index(inplace=True)

# %%
vendas_2018_por_mes
# Out:
#    Mes  Total Value
# 0    3   248866.380
# 1    4   249913.440
# 2    5   267427.440
# 3    6   349034.280
# 4    7   353761.380
# 5    8   355573.148
# 6    9   328287.120
# 7   10   291943.260
# 8   11   370068.300
# 9   12   474786.060

# %%
vendas_2019_por_mes = vendas_2019.groupby('Mes')['Total Value'].sum()
vendas_2019_por_mes = pd.DataFrame(vendas_2019_por_mes)
vendas_2019_por_mes.reset_index(inplace=True)
vendas_2019_por_mes
# Out:
#     Mes  Total Value
# 0     1   210849.660
# 1     2   168483.420
# 2     3   285083.820
# 3     4   257972.400
# 4     5   283353.840
# 5     6   454739.992
# 6     7   242757.900
# 7     8   456192.856
# 8     9   256809.420
# 9    10   225986.040
# 10   11   248448.060
# 11   12   440503.728

# %%
vendas_2020_por_mes = vendas_2020.groupby('Mes')['Total Value'].sum()
vendas_2020_por_mes = pd.DataFrame(vendas_2020_por_mes)
vendas_2020_por_mes.reset_index(inplace=True)
vendas_2020_por_mes
# Out:
#    Mes  Total Value
# 0    1    153009.36

# %%
sns.barplot(x=vendas_2018_por_mes.Mes, y= vendas_2018_por_mes['Total Value'])
# Out:
# <AxesSubplot:xlabel='Mes', ylabel='Total Value'>

# %%
sns.barplot(x=vendas_2019_por_mes.Mes, y= vendas_2019_por_mes['Total Value'])
# Out:
# <AxesSubplot:xlabel='Mes', ylabel='Total Value'>

# %%
# sns.barplot(x=vendas_2020_por_mes.Mes, y= vendas_2020_por_mes['Total Value'])
# O Gráfico referente a 2020 só contém o mês de Janeiro, portanto ficará oculto

# %% [markdown]
# ###Calculando Média, Mediana e Desvio Padrão por ano

# %% [markdown]
# **2018**

# %%
vendas_2018_por_mes['Total Value'].mean()
# Out:
# 328966.0808

# %%
vendas_2018_por_mes['Total Value'].median()
# Out:
# 338660.69999999995

# %%
vendas_2018_por_mes['Total Value'].std()
# Out:
# 68719.85877342768

# %% [markdown]
# **2019**

# %%
vendas_2019_por_mes['Total Value'].mean()
# Out:
# 294265.0946666667

# %%
vendas_2019_por_mes['Total Value'].median()
# Out:
# 257390.90999999997

# %%
vendas_2019_por_mes['Total Value'].std()
# Out:
# 99304.56113044302
